# %%
import cloudscraper
from bs4 import BeautifulSoup
import re

# %%
scraper = cloudscraper.create_scraper()  # returns a CloudScraper instance
matches_url = "https://csgostats.gg/match"
content = scraper.get(matches_url).text

# %%
soup = BeautifulSoup(content , 'html.parser')

from datetime import datetime , timedelta
import attr
from attr import validators
from collections import defaultdict
from urllib.parse import urljoin
from typing import Dict , Union , List

def calculate_datetime(time_of_logging):
    return (datetime.now() - timedelta(minutes = int(time_of_logging.split(' ')[0]))).strftime('%Y-%m-%d %H-%M-%S')
    

class Chameleon:
        
    def __init__(self , url : str) -> None:
        self.url = str(url)
        self.scraper = cloudscraper.create_scraper()
        self.soup = None
        
    def observe(self , **kwargs) -> bool:
        try:
            self.soup = BeautifulSoup( self.scraper.get( urljoin(self.url , 
                                                                 self.get_endpoint(**kwargs)) ).text , 
                                      'html.parser')
            return True
        except Exception as e:
            print(e)
            return False
        
    def get_endpoint(self) -> str:
        pass
        
    def parse(self):
        pass
    

class CSGOChameleon(Chameleon):
    
    endpoints = {'MatchesChameleon':'matches',
                 'PlayersChameleon':'leaderboards',
                 'MatchesDetailsChameleon':''}
    
    def __init__(self):
        super().__init__('https://csgostats.gg')
        
    def get_endpoint(self) -> str:
        return CSGOChameleon.endpoints.get(type(self).__name__)
        
        
class MatchesChameleon(CSGOChameleon):
    
    def parse(self) -> Dict[str, Union[str , List[str] , int]]:
        all_matches = []
        
        for soupie in self.soup.find_all('tr', {'class':'p-row js-link'}):
            match_id = re.findall( r'match/(\d+)' , soupie.attrs['onclick'])[0]

            csmap = soupie.find('img' , {'title':re.compile(r'de_*')}).attrs['title']

            rank = soupie.find('img', {'src':re.compile(r'ranks')}).attrs['title']

            teams = list(map(lambda x : x.attrs['title'] , 
                             soupie.find_all('img',{'src':re.compile(r'avatars')})
                            )
                        )
            t_team , ct_team = teams[:5] , teams[5:]

            date = calculate_datetime(soupie.find('td',{'class':'nowrap'}).string.strip())

            matches['match_id'] = match_id
            matches['map'] = csmap
            matches['date'] = date
            matches['rank'] = rank
            matches['players'] = {'ct_team': ct_team,
                                   't_team': t_team}
            yield matches
            
            
class PlayersChameleon(CSGOChameleon):
    
    def get_endpoint(self , page : int) -> str:
        return super().get_endpoint() + f'?page={page}'
    
    def parse(self):
        player_data = []
        for soupie in self.soup.find_all('div',{'onclick':re.compile(r'player')}):
            player_id = re.findall( r'player/(\d+)' , soupie.attrs['onclick'])[0]

            player_name = soupie.find('a').text.strip('\n').strip()
            weapons = soupie.find_all('img',{'src': re.compile(r'weapons')})
            primary_weapon = weapons[0].attrs['title']
            secondary_weapon = weapons[1].attrs['title']

            cake = soupie.find_all('div' , {'style':'float:left; width:10%;text-align:center;'})[2:]
            kd = cake[0].find('span').string.strip()
            hs = cake[1].string
            win_rate = cake[2].next_element.strip('\n').strip()
            vx = cake[3].string
            rating = cake[4].string

            player_data.append( {'player_id' : player_id,
                                 'player_name': player_name,
                                 'primary_weapon' : primary_weapon,
                                 'secondary_weapon': secondary_weapon,
                                 'kd': kd,
                                 'hs':hs,
                                 'win_rate':win_rate,
                                 'rating':rating
                                 })
        return player_data
            
    
class MatchesDetailsChameleon(Chameleon):
    
    def parse(self):
        rounds = {'round_id' : ''}

        for round_ , soupie in enumerate(soup.find_all('div', class_ = 'round-info-side')):
            if not round_%2:
                continue
                
            round_stats = defaultdict(list)

            for cake in soupie.find_all('div', class_ = 'tl-inner'):

                ##get time
                time = cake.find('span', {'title': re.compile(r'Tick*')}).string
                round_stats["Times"].append(time)

                ##killing team
                killer_team = cake.find('span' , {'class': re.compile(r'team')})\
                                  .attrs['class'][0].split('-')[-1]

                ##actors
                actors = list(map( lambda x : x.string , 
                            cake.find_all('span' , {'class': re.compile(r'team-')})))

                killers = ', '.join(actors[:-1])
                dead = actors[-1]
                round_stats["Actors"].append(killers)
                round_stats["Target"].append(dead)

                ##weapon
                weapon_headshot = cake.find_all('img')
                round_stats['Weapon'].append(weapon_headshot[0].attrs['title'])

                ##headshot
                headshot = len(weapon_headshot) > 1
                round_stats["Headshot"].append(headshot)

            ##winner
            winner = soupie.find('span',class_ = 'attacker').string.strip('\n').strip()
            round_stats['Winner'].append(winner)


            rounds.update({round_: round_stats})
        return rounds

# %%
cham = PlayersChameleon()
cham.observe(page = 2)
# Out:
# True

# %%
cham.parse()
# Out:
# [{'player_id': '76561198135668261',
#   'player_name': 'BRIVES',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'deagle',
#   'kd': '167 / 49',
#   'hs': '53%',
#   'win_rate': '90%',
#   'rating': '2.17'},
#  {'player_id': '76561198886280955',
#   'player_name': 'Pedo Pan',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '291 / 104',
#   'hs': '61%',
#   'win_rate': '90%',
#   'rating': '2.16'},
#  {'player_id': '76561198173297394',
#   'player_name': 'WACHO',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '312 / 139',
#   'hs': '40%',
#   'win_rate': '70%',
#   'rating': '2.16'},
#  {'player_id': '76561198423385704',
#   'player_name': 'Aevu',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '124 / 25',
#   'hs': '46%',
#   'win_rate': '100%',
#   'rating': '2.16'},
#  {'player_id': '76561198262126621',
#   'player_name': 'h0le',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '193 / 78',
#   'hs': '38%',
#   'win_rate': '80%',
#   'rating': '2.16'},
#  {'player_id': '76561199071473200',
#   'player_name': '9361599',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '337 / 144',
#   'hs': '56%',
#   'win_rate': '80%',
#   'rating': '2.15'},
#  {'player_id': '76561198919711517',
#   'player_name': 'ontoshqa',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '124 / 32',
#   'hs': '55%',
#   'win_rate': '100%',
#   'rating': '2.15'},
#  {'player_id': '76561198049295175',
#   'player_name': 'jNN       10[!]',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '264 / 104',
#   'hs': '44%',
#   'win_rate': '70%',
#   'rating': '2.14'},
#  {'player_id': '76561199106829135',
#   'player_name': 'moppii1337 #FreeUkraine',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '355 / 139',
#   'hs': '44%',
#   'win_rate': '80%',
#   'rating': '2.14'},
#  {'player_id': '76561198276700997',
#   'player_name': '76561198276700997',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'awp',
#   'kd': '124 / 39',
#   'hs': '69%',
#   'win_rate': '90%',
#   'rating': '2.14'},
#  {'player_id': '76561199127667944',
#   'player_name': 'Lex',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '219 / 84',
#   'hs': '55%',
#   'win_rate': '70%',
#   'rating': '2.14'},
#  {'player_id': '76561197997059622',
#   'player_name': '𝓢𝓵𝓪𝔂𝓮𝓻',
#   'primary_weapon': 'deagle',
#   'secondary_weapon': 'awp',
#   'kd': '293 / 109',
#   'hs': '52%',
#   'win_rate': '100%',
#   'rating': '2.14'},
#  {'player_id': '76561198142698374',
#   'player_name': '✪LuKziN',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '300 / 132',
#   'hs': '42%',
#   'win_rate': '70%',
#   'rating': '2.13'},
#  {'player_id': '76561198353642958',
#   'player_name': '𝘼𝙡𝙚𝙭',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'usp_silencer',
#   'kd': '127 / 35',
#   'hs': '44%',
#   'win_rate': '100%',
#   'rating': '2.13'},
#  {'player_id': '76561199140576169',
#   'player_name': 'ǝɔıxopɐɹɐԀ',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'awp',
#   'kd': '268 / 102',
#   'hs': '69%',
#   'win_rate': '100%',
#   'rating': '2.13'},
#  {'player_id': '76561198342928821',
#   'player_name': 'AlexFren',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '226 / 91',
#   'hs': '49%',
#   'win_rate': '90%',
#   'rating': '2.13'},
#  {'player_id': '76561198174748101',
#   'player_name': 'UNDERCOVER',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '339 / 134',
#   'hs': '54%',
#   'win_rate': '90%',
#   'rating': '2.12'},
#  {'player_id': '76561198080767090',
#   'player_name': 'TΞЯЯOЯ BALΞIЯO',
#   'primary_weapon': 'g3sg1',
#   'secondary_weapon': 'ak47',
#   'kd': '207 / 74',
#   'hs': '48%',
#   'win_rate': '100%',
#   'rating': '2.11'},
#  {'player_id': '76561198047201834',
#   'player_name': 'neadek',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ak47',
#   'kd': '284 / 97',
#   'hs': '43%',
#   'win_rate': '100%',
#   'rating': '2.11'},
#  {'player_id': '76561198153894531',
#   'player_name': 'うちは・マダラ',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '337 / 131',
#   'hs': '38%',
#   'win_rate': '100%',
#   'rating': '2.11'},
#  {'player_id': '76561197996326391',
#   'player_name': 'call an ambulance',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '324 / 120',
#   'hs': '29%',
#   'win_rate': '70%',
#   'rating': '2.11'},
#  {'player_id': '76561198168694063',
#   'player_name': 'mooncak3',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '344 / 144',
#   'hs': '56%',
#   'win_rate': '60%',
#   'rating': '2.1'},
#  {'player_id': '76561198001679019',
#   'player_name': '666',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '307 / 120',
#   'hs': '49%',
#   'win_rate': '100%',
#   'rating': '2.1'},
#  {'player_id': '76561198050632574',
#   'player_name': '♢ Forexxa ❤ Ela',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '351 / 157',
#   'hs': '54%',
#   'win_rate': '80%',
#   'rating': '2.1'},
#  {'player_id': '76561198387735604',
#   'player_name': 'random',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'deagle',
#   'kd': '131 / 57',
#   'hs': '53%',
#   'win_rate': '80%',
#   'rating': '2.1'},
#  {'player_id': '76561198153248268',
#   'player_name': '無題',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '221 / 86',
#   'hs': '63%',
#   'win_rate': '100%',
#   'rating': '2.1'},
#  {'player_id': '76561198275054116',
#   'player_name': 'fNX',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '366 / 151',
#   'hs': '63%',
#   'win_rate': '90%',
#   'rating': '2.1'},
#  {'player_id': '76561197993854416',
#   'player_name': '',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '149 / 46',
#   'hs': '51%',
#   'win_rate': '100%',
#   'rating': '2.09'},
#  {'player_id': '76561198080786977',
#   'player_name': 'avarice',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'awp',
#   'kd': '130 / 44',
#   'hs': '62%',
#   'win_rate': '80%',
#   'rating': '2.09'},
#  {'player_id': '76561198109589290',
#   'player_name': 'Pus1_abba',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '214 / 74',
#   'hs': '31%',
#   'win_rate': '40%',
#   'rating': '2.09'},
#  {'player_id': '76561198980506380',
#   'player_name': 'ari',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '246 / 106',
#   'hs': '63%',
#   'win_rate': '90%',
#   'rating': '2.09'},
#  {'player_id': '76561198025620309',
#   'player_name': 'Mr. Frostyzer4',
#   'primary_weapon': 'm4a1',
#   'secondary_weapon': 'awp',
#   'kd': '143 / 47',
#   'hs': '56%',
#   'win_rate': '100%',
#   'rating': '2.08'},
#  {'player_id': '76561198817260678',
#   'player_name': '★ K1NQZ0R -魔-',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ak47',
#   'kd': '126 / 46',
#   'hs': '57%',
#   'win_rate': '90%',
#   'rating': '2.08'},
#  {'player_id': '76561198445513255',
#   'player_name': 'sdk',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '196 / 86',
#   'hs': '48%',
#   'win_rate': '60%',
#   'rating': '2.08'},
#  {'player_id': '76561199215840265',
#   'player_name': 'cat-meow-cute-cat-gif-24423734',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'revolver',
#   'kd': '101 / 27',
#   'hs': '43%',
#   'win_rate': '90%',
#   'rating': '2.08'},
#  {'player_id': '76561199026004420',
#   'player_name': 'Easy Drop',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '312 / 117',
#   'hs': '49%',
#   'win_rate': '80%',
#   'rating': '2.08'},
#  {'player_id': '76561198083780806',
#   'player_name': '𝗱𝗮𝗴𝗲;',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '233 / 67',
#   'hs': '35%',
#   'win_rate': '100%',
#   'rating': '2.07'},
#  {'player_id': '76561198262528830',
#   'player_name': '@yungluzha342',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '293 / 118',
#   'hs': '55%',
#   'win_rate': '90%',
#   'rating': '2.07'},
#  {'player_id': '76561199098253936',
#   'player_name': 'suke',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '166 / 70',
#   'hs': '50%',
#   'win_rate': '80%',
#   'rating': '2.07'},
#  {'player_id': '76561199056651310',
#   'player_name': 'purity',
#   'primary_weapon': 'deagle',
#   'secondary_weapon': 'awp',
#   'kd': '267 / 110',
#   'hs': '74%',
#   'win_rate': '80%',
#   'rating': '2.07'},
#  {'player_id': '76561197990308022',
#   'player_name': 'baby SHinyzinho',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'awp',
#   'kd': '212 / 82',
#   'hs': '61%',
#   'win_rate': '90%',
#   'rating': '2.07'},
#  {'player_id': '76561198005726098',
#   'player_name': 'vsd',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ak47',
#   'kd': '290 / 105',
#   'hs': '57%',
#   'win_rate': '100%',
#   'rating': '2.07'},
#  {'player_id': '76561198315965573',
#   'player_name': '【 4\u3000ｄａｙｓ】',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '281 / 107',
#   'hs': '59%',
#   'win_rate': '60%',
#   'rating': '2.07'},
#  {'player_id': '76561199060488152',
#   'player_name': 'Aeci',
#   'primary_weapon': 'deagle',
#   'secondary_weapon': 'ssg08',
#   'kd': '134 / 52',
#   'hs': '64%',
#   'win_rate': '90%',
#   'rating': '2.07'},
#  {'player_id': '76561198426564574',
#   'player_name': 'Guckst, Muckst, Zähne spuckst',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'ak47',
#   'kd': '183 / 60',
#   'hs': '62%',
#   'win_rate': '90%',
#   'rating': '2.06'},
#  {'player_id': '76561198167785459',
#   'player_name': 'Pokéchifre #HSMachine 💙',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ssg08',
#   'kd': '289 / 103',
#   'hs': '61%',
#   'win_rate': '90%',
#   'rating': '2.06'},
#  {'player_id': '76561199073006100',
#   'player_name': 'millionaire',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '122 / 23',
#   'hs': '35%',
#   'win_rate': '100%',
#   'rating': '2.06'},
#  {'player_id': '76561198280430105',
#   'player_name': '✪ Berserk',
#   'primary_weapon': 'm4a1',
#   'secondary_weapon': 'ak47',
#   'kd': '227 / 58',
#   'hs': '52%',
#   'win_rate': '100%',
#   'rating': '2.06'},
#  {'player_id': '76561199011920537',
#   'player_name': '✪Gentukiツ',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '302 / 121',
#   'hs': '47%',
#   'win_rate': '90%',
#   'rating': '2.06'},
#  {'player_id': '76561198287961350',
#   'player_name': 'AFF',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '270 / 102',
#   'hs': '36%',
#   'win_rate': '100%',
#   'rating': '2.05'},
#  {'player_id': '76561199150295808',
#   'player_name': 'K i z z y',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '147 / 55',
#   'hs': '53%',
#   'win_rate': '80%',
#   'rating': '2.05'},
#  {'player_id': '76561199060007437',
#   'player_name': 'The Emperor',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '264 / 99',
#   'hs': '39%',
#   'win_rate': '80%',
#   'rating': '2.05'},
#  {'player_id': '76561198163892195',
#   'player_name': 'Sinan_Racing',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '364 / 171',
#   'hs': '36%',
#   'win_rate': '50%',
#   'rating': '2.05'},
#  {'player_id': '76561198802856223',
#   'player_name': 'Shadowyeye',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '304 / 135',
#   'hs': '35%',
#   'win_rate': '70%',
#   'rating': '2.05'},
#  {'player_id': '76561198020901572',
#   'player_name': 'mem',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '285 / 119',
#   'hs': '40%',
#   'win_rate': '90%',
#   'rating': '2.05'},
#  {'player_id': '76561199073165104',
#   'player_name': 'Glizzy Guzzler',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'ak47',
#   'kd': '302 / 162',
#   'hs': '48%',
#   'win_rate': '40%',
#   'rating': '2.05'},
#  {'player_id': '76561198071035098',
#   'player_name': 'Shobira',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '200 / 66',
#   'hs': '54%',
#   'win_rate': '100%',
#   'rating': '2.05'},
#  {'player_id': '76561198411278119',
#   'player_name': 'highter',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '288 / 140',
#   'hs': '48%',
#   'win_rate': '70%',
#   'rating': '2.04'},
#  {'player_id': '76561198973790279',
#   'player_name': '\U000e0073\u2067\u2067 braxzen',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '220 / 101',
#   'hs': '55%',
#   'win_rate': '70%',
#   'rating': '2.04'},
#  {'player_id': '76561199230539233',
#   'player_name': 'Murphy',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '178 / 66',
#   'hs': '38%',
#   'win_rate': '70%',
#   'rating': '2.04'},
#  {'player_id': '76561198841875851',
#   'player_name': 'exotik',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'm4a1_silencer_off',
#   'kd': '122 / 24',
#   'hs': '64%',
#   'win_rate': '100%',
#   'rating': '2.04'},
#  {'player_id': '76561199070831501',
#   'player_name': 'kys all',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ak47',
#   'kd': '171 / 74',
#   'hs': '30%',
#   'win_rate': '80%',
#   'rating': '2.04'},
#  {'player_id': '76561198965237010',
#   'player_name': 'AE / Macaquinho',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '387 / 190',
#   'hs': '45%',
#   'win_rate': '70%',
#   'rating': '2.04'},
#  {'player_id': '76561198095960193',
#   'player_name': '†𝒂𝒏𝒈𝒆𝒍.𝒊𝒏',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '281 / 122',
#   'hs': '54%',
#   'win_rate': '60%',
#   'rating': '2.04'},
#  {'player_id': '76561198136591435',
#   'player_name': 'SkinNy',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '267 / 131',
#   'hs': '45%',
#   'win_rate': '80%',
#   'rating': '2.04'},
#  {'player_id': '76561198139841230',
#   'player_name': 'pan1c',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '331 / 146',
#   'hs': '49%',
#   'win_rate': '60%',
#   'rating': '2.04'},
#  {'player_id': '76561198985742780',
#   'player_name': 'grimes',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '262 / 92',
#   'hs': '62%',
#   'win_rate': '80%',
#   'rating': '2.04'},
#  {'player_id': '76561198924100092',
#   'player_name': 'NianYT',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '201 / 52',
#   'hs': '61%',
#   'win_rate': '100%',
#   'rating': '2.04'},
#  {'player_id': '76561198800024617',
#   'player_name': '♥ Lov3b1rd ♥',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '179 / 80',
#   'hs': '48%',
#   'win_rate': '70%',
#   'rating': '2.04'},
#  {'player_id': '76561198976795150',
#   'player_name': 'idkwhatname',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '276 / 108',
#   'hs': '60%',
#   'win_rate': '80%',
#   'rating': '2.04'},
#  {'player_id': '76561198250616650',
#   'player_name': 'Csabibácsi!!!!!',
#   'primary_weapon': 'm4a1_silencer',
#   'secondary_weapon': 'ak47',
#   'kd': '349 / 148',
#   'hs': '55%',
#   'win_rate': '80%',
#   'rating': '2.03'},
#  {'player_id': '76561198360381018',
#   'player_name': 'LuKas',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '240 / 114',
#   'hs': '58%',
#   'win_rate': '70%',
#   'rating': '2.03'},
#  {'player_id': '76561198396082438',
#   'player_name': 'QµÏ?!',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '215 / 73',
#   'hs': '51%',
#   'win_rate': '100%',
#   'rating': '2.03'},
#  {'player_id': '76561198070468233',
#   'player_name': 'FROZ3N',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '316 / 126',
#   'hs': '58%',
#   'win_rate': '80%',
#   'rating': '2.03'},
#  {'player_id': '76561198170166522',
#   'player_name': '$$$',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '261 / 109',
#   'hs': '46%',
#   'win_rate': '100%',
#   'rating': '2.03'},
#  {'player_id': '76561198185234933',
#   'player_name': 'cheese',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '232 / 104',
#   'hs': '33%',
#   'win_rate': '100%',
#   'rating': '2.02'},
#  {'player_id': '76561198357088831',
#   'player_name': 'allus1on',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '204 / 56',
#   'hs': '53%',
#   'win_rate': '100%',
#   'rating': '2.02'},
#  {'player_id': '76561198970243762',
#   'player_name': 'Alphonse Karr',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '318 / 156',
#   'hs': '43%',
#   'win_rate': '80%',
#   'rating': '2.01'},
#  {'player_id': '76561198867157318',
#   'player_name': '⑳ tiago s2',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '266 / 91',
#   'hs': '33%',
#   'win_rate': '100%',
#   'rating': '2.01'},
#  {'player_id': '76561199080120316',
#   'player_name': 'Player Two',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '277 / 119',
#   'hs': '31%',
#   'win_rate': '70%',
#   'rating': '2.01'},
#  {'player_id': '76561198272010450',
#   'player_name': '𝓭𝓮𝓶𝓾𝓻𝓮',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '298 / 123',
#   'hs': '53%',
#   'win_rate': '100%',
#   'rating': '2.01'},
#  {'player_id': '76561198939950677',
#   'player_name': 'DestroyerPlus',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '322 / 132',
#   'hs': '40%',
#   'win_rate': '80%',
#   'rating': '2.01'},
#  {'player_id': '76561199075981359',
#   'player_name': 'animated',
#   'primary_weapon': 'scar20',
#   'secondary_weapon': 'ssg08',
#   'kd': '100 / 34',
#   'hs': '30%',
#   'win_rate': '80%',
#   'rating': '2.01'},
#  {'player_id': '76561199234896703',
#   'player_name': 'Ally',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'glock',
#   'kd': '126 / 50',
#   'hs': '55%',
#   'win_rate': '100%',
#   'rating': '2.01'},
#  {'player_id': '76561198859317788',
#   'player_name': 'starlight',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '206 / 65',
#   'hs': '58%',
#   'win_rate': '100%',
#   'rating': '2'},
#  {'player_id': '76561199238914541',
#   'player_name': '𝐻𝓎𝑜𝑜𝓃',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'ak47',
#   'kd': '268 / 123',
#   'hs': '53%',
#   'win_rate': '100%',
#   'rating': '2'},
#  {'player_id': '76561198123607652',
#   'player_name': '🇧 🇦 🇩 🇲 🇦 🇳',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '310 / 152',
#   'hs': '62%',
#   'win_rate': '80%',
#   'rating': '2'},
#  {'player_id': '76561198263286912',
#   'player_name': 'lane1ge-',
#   'primary_weapon': 'ssg08',
#   'secondary_weapon': 'ak47',
#   'kd': '236 / 120',
#   'hs': '70%',
#   'win_rate': '80%',
#   'rating': '2'},
#  {'player_id': '76561198051358818',
#   'player_name': '8FulGod',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '155 / 66',
#   'hs': '36%',
#   'win_rate': '70%',
#   'rating': '2'},
#  {'player_id': '76561199014803106',
#   'player_name': 'ломаю колени.',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '196 / 83',
#   'hs': '57%',
#   'win_rate': '60%',
#   'rating': '2'},
#  {'player_id': '76561198986016450',
#   'player_name': 'V1per',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '294 / 120',
#   'hs': '24%',
#   'win_rate': '90%',
#   'rating': '1.99'},
#  {'player_id': '76561198863296777',
#   'player_name': 'Rxndy',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ak47',
#   'kd': '280 / 117',
#   'hs': '38%',
#   'win_rate': '90%',
#   'rating': '1.99'},
#  {'player_id': '76561198836119507',
#   'player_name': 'BaLLaZ',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'usp_silencer',
#   'kd': '168 / 70',
#   'hs': '50%',
#   'win_rate': '100%',
#   'rating': '1.99'},
#  {'player_id': '76561198447418055',
#   'player_name': 'ГрЕш(НиК)Gg💯',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '205 / 85',
#   'hs': '34%',
#   'win_rate': '80%',
#   'rating': '1.99'},
#  {'player_id': '76561198086001486',
#   'player_name': 'P A P A M I C A',
#   'primary_weapon': 'deagle',
#   'secondary_weapon': 'awp',
#   'kd': '338 / 170',
#   'hs': '64%',
#   'win_rate': '60%',
#   'rating': '1.99'},
#  {'player_id': '76561198143507419',
#   'player_name': 'tr1',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'deagle',
#   'kd': '348 / 166',
#   'hs': '63%',
#   'win_rate': '100%',
#   'rating': '1.99'},
#  {'player_id': '76561198229400604',
#   'player_name': 'Talha',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'awp',
#   'kd': '274 / 100',
#   'hs': '53%',
#   'win_rate': '90%',
#   'rating': '1.98'},
#  {'player_id': '76561198453821169',
#   'player_name': '🆆 🅶🅰🅼🅸🅽🅶',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'deagle',
#   'kd': '177 / 58',
#   'hs': '43%',
#   'win_rate': '90%',
#   'rating': '1.98'},
#  {'player_id': '76561198359976203',
#   'player_name': '𝕯𝖊𝖓𝖌𝖊 ☠',
#   'primary_weapon': 'ak47',
#   'secondary_weapon': 'm4a1_silencer',
#   'kd': '226 / 76',
#   'hs': '40%',
#   'win_rate': '100%',
#   'rating': '1.98'},
#  {'player_id': '76561198280972206',
#   'player_name': 'fort',
#   'primary_weapon': 'awp',
#   'secondary_weapon': 'ssg08',
#   'kd': '155 / 47',
#   'hs': '45%',
#   'win_rate': '100%',
#   'rating': '1.98'}]

# %%
scraper = cloudscraper.create_scraper()
matches_url = "https://csgostats.gg/leaderboards"
content = scraper.get(matches_url).text

# %%
soup = BeautifulSoup( content , 'html.parser')
player_data = []
for soupie in soup.find_all('div',{'onclick':re.compile(r'player')}):
    player_id = re.findall( r'player/(\d+)' , soupie.attrs['onclick'])[0]
    
    player_name = soupie.find('a').text.strip('\n').strip()
    weapons = soupie.find_all('img',{'src': re.compile(r'weapons')})
    primary_weapon = weapons[0].attrs['title']
    secondary_weapon = weapons[1].attrs['title']
    
    cake = soupie.find_all('div' , {'style':'float:left; width:10%;text-align:center;'})[2:]
    kd = cake[0].find('span').string.strip()
    hs = cake[1].string
    win_rate = cake[2].next_element.strip('\n').strip()
    vx = cake[3].string
    rating = cake[4].string

    player_data.append( {'player_id' : player_id,
                         'player_name': player_name,
                         'primary_weapon' : primary_weapon,
                         'secondary_weapon': secondary_weapon,
                         'kd': kd,
                         'hs':hs,
                         'win_rate':win_rate,
                         'rating':rating
                         })
    player_data
# Out:
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}, {'player_id': '76561198857704900', 'player_name': 'Mefedron', 'primary_weapon': 'awp', 'secondary_weapon': 'm4a1_silencer', 'kd': '238 / 51', 'hs': '61%', 'win_rate': '90%', 'rating': '2.66'}]
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}, {'player_id': '76561198857704900', 'player_name': 'Mefedron', 'primary_weapon': 'awp', 'secondary_weapon': 'm4a1_silencer', 'kd': '238 / 51', 'hs': '61%', 'win_rate': '90%', 'rating': '2.66'}, {'player_id': '76561198000401762', 'player_name': 'jstce', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '312 / 99', 'hs': '62%', 'win_rate': '90%', 'rating': '2.66'}]
# ...
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}, {'player_id': '76561198857704900', 'player_name': 'Mefedron', 'primary_weapon': 'awp', 'secondary_weapon': 'm4a1_silencer', 'kd': '238 / 51', 'hs': '61%', 'win_rate': '90%', 'rating': '2.66'}, {'player_id': '76561198000401762', 'player_name': 'jstce', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '312 / 99', 'hs': '62%', 'win_rate': '90%', 'rating': '2.66'}, {'player ...
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}, {'player_id': '76561198857704900', 'player_name': 'Mefedron', 'primary_weapon': 'awp', 'secondary_weapon': 'm4a1_silencer', 'kd': '238 / 51', 'hs': '61%', 'win_rate': '90%', 'rating': '2.66'}, {'player_id': '76561198000401762', 'player_name': 'jstce', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '312 / 99', 'hs': '62%', 'win_rate': '90%', 'rating': '2.66'}, {'player ...
# [{'player_id': '76561199257950294', 'player_name': 'RETIRED DONT INVITE', 'primary_weapon': 'ssg08', 'secondary_weapon': 'usp_silencer', 'kd': '182 / 10', 'hs': '85%', 'win_rate': '100%', 'rating': '4.53'}, {'player_id': '76561198971823213', 'player_name': 'canadian egirl', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '265 / 34', 'hs': '65%', 'win_rate': '100%', 'rating': '3.72'}, {'player_id': '76561198199861325', 'player_name': 'swedish autotune guy', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '200 / 38', 'hs': '64%', 'win_rate': '100%', 'rating': '3.63'}, {'player_id': '76561199275017807', 'player_name': 'pro usp user', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '309 / 59', 'hs': '53%', 'win_rate': '80%', 'rating': '3.58'}, {'player_id': '76561199112388455', 'player_name': 'wwwwwwwww', 'primary_weapon': 'usp_silencer', 'secondary_weapon': 'ak47', 'kd': '100 / 27', 'hs': '61%', 'win_rate': '80%', 'rating': '3.47'}, {'player_id': '76561198246707610', 'player_name': 'fah fah fah', 'primary_weapon': 'deagle', 'secondary_weapon': 'awp', 'kd': '124 / 20', 'hs': '65%', 'win_rate': '90%', 'rating': '3.11'}, {'player_id': '76561199207848326', 'player_name': 'soap', 'primary_weapon': 'mp9', 'secondary_weapon': 'deagle', 'kd': '129 / 15', 'hs': '54%', 'win_rate': '100%', 'rating': '3.06'}, {'player_id': '76561199105612758', 'player_name': 'ОЛЕГ', 'primary_weapon': 'deagle', 'secondary_weapon': 'usp_silencer', 'kd': '247 / 51', 'hs': '83%', 'win_rate': '80%', 'rating': '2.98'}, {'player_id': '76561199044361978', 'player_name': 'sippin toseina', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '166 / 38', 'hs': '72%', 'win_rate': '80%', 'rating': '2.95'}, {'player_id': '76561199205606095', 'player_name': 'rodode PRINGAO', 'primary_weapon': 'ssg08', 'secondary_weapon': 'deagle', 'kd': '307 / 77', 'hs': '59%', 'win_rate': '80%', 'rating': '2.92'}, {'player_id': '76561198262569990', 'player_name': 'ｈｅｗｉ乡', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '340 / 90', 'hs': '61%', 'win_rate': '80%', 'rating': '2.87'}, {'player_id': '76561198810095624', 'player_name': 'Sophia <3', 'primary_weapon': 'ssg08', 'secondary_weapon': 'ak47', 'kd': '234 / 56', 'hs': '45%', 'win_rate': '100%', 'rating': '2.86'}, {'player_id': '76561198055080400', 'player_name': 'saint', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '427 / 119', 'hs': '42%', 'win_rate': '90%', 'rating': '2.86'}, {'player_id': '76561197968118149', 'player_name': 'lpck', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '322 / 99', 'hs': '31%', 'win_rate': '50%', 'rating': '2.79'}, {'player_id': '76561199232735455', 'player_name': 'Abdullah', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '259 / 83', 'hs': '75%', 'win_rate': '70%', 'rating': '2.75'}, {'player_id': '76561197966916876', 'player_name': 'kizzamp. -Q-', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '436 / 160', 'hs': '58%', 'win_rate': '50%', 'rating': '2.75'}, {'player_id': '76561198437208083', 'player_name': 'Bot-Jacob', 'primary_weapon': 'ssg08', 'secondary_weapon': 'awp', 'kd': '362 / 112', 'hs': '58%', 'win_rate': '100%', 'rating': '2.69'}, {'player_id': '76561198276456548', 'player_name': '76561198276456548', 'primary_weapon': 'awp', 'secondary_weapon': 'ssg08', 'kd': '258 / 69', 'hs': '34%', 'win_rate': '100%', 'rating': '2.68'}, {'player_id': '76561199017962201', 'player_name': 'noob', 'primary_weapon': 'awp', 'secondary_weapon': 'ak47', 'kd': '343 / 88', 'hs': '54%', 'win_rate': '70%', 'rating': '2.66'}, {'player_id': '76561198857704900', 'player_name': 'Mefedron', 'primary_weapon': 'awp', 'secondary_weapon': 'm4a1_silencer', 'kd': '238 / 51', 'hs': '61%', 'win_rate': '90%', 'rating': '2.66'}, {'player_id': '76561198000401762', 'player_name': 'jstce', 'primary_weapon': 'ak47', 'secondary_weapon': 'm4a1_silencer', 'kd': '312 / 99', 'hs': '62%', 'win_rate': '90%', 'rating': '2.66'}, {'player ...

# %%
chameleon = MatchesChameleon(matches_url)

# %%
for x in chameleon.parse():
    print(x)
    break
# Out:
# ['68033712']
# {'match_id': [], 'date': '2022-06-02 21-32-44', 'map': 'de_ancient', 'players': {'ct_team': ['207', 'Kudia', 'GG', 'your bunny wrote', 'El Johnny'], 't_team': ['No Flex', 'kAr0', 'eLTac ♥ᶠᶸᶜᵏᵧₒᵤ♥', 'Kronislaw Bomorowski', 'cr1s.']}, 'rank': 'Distinguished Master Guardian'}

# %%
soup.find_all('div', {'class':'p-row js-link'})
# Out:
# []

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 6, 2, 21, 31, 2, 852419)
